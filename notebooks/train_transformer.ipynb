# %% [markdown]
# <a href="https://colab.research.google.com/github/azhgh22/Comparative-analysis-of-Generative-models-on-CIFAR-10/blob/main/notebooks/train_transformer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Set Env**

# %%
# %%capture
from google.colab import drive
drive.mount('/content/drive')

from google.colab import userdata
token = userdata.get('GITHUB_TOKEN')
user_name = userdata.get('GITHUB_USERNAME')
mail = userdata.get('GITHUB_MAIL')

# !git config --global user.name "{user_name}"
# !git config --global user.email "{mail}"
# !git clone https://{token}@github.com/nmach22/Promoter-Classification.git
# !pip install -r ./Promoter-Classification/requirements.txt

# %% [markdown]
# # **Imports**

# %%
# Imports
import sys
import os
import torch
import yaml
import matplotlib.pyplot as plt
import torch
import numpy as np
import torchvision.transforms as transforms
from torchvision.utils import make_grid
from torch.utils.data import random_split
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Add the root directory of the cloned repository to the Python path
ROOT_DIR = '/content/Promoter-Classification'
sys.path.append(ROOT_DIR)


import importlib
import utils.fasta_dataset as dataset_module
import utils.encoding_functions as encoding_module
import utils.data_split as splitter_module
import models.transformer as transformer_module
import utils.train as train_module
import eval.train_evals as eval_module
import eval.metrics as metrics_module
importlib.reload(dataset_module)
importlib.reload(encoding_module)
importlib.reload(transformer_module)
importlib.reload(train_module)
importlib.reload(eval_module)
importlib.reload(metrics_module)
from utils.fasta_dataset import FastaDataset
from utils.encoding_functions import *
from models.transformer import DNATransformer
from utils.data_split import dataset_split
from utils.train import Train
from eval.train_evals import TrainEvals
from eval.metrics import *

with open(f"{ROOT_DIR}/config/config.yaml", "r") as f:
    config = yaml.safe_load(f)

print(config.keys())

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# dict_keys(['data', 'dataset_split', 'train'])
# cuda

# %% [markdown]
# # **Read Data**

# %%
ecoli_data = config['data']['arabidopsis_tata']

prom_path = f"{ROOT_DIR}/{ecoli_data['promoter_fasta']}"
non_prom_path = f"{ROOT_DIR}/{ecoli_data['non_promoter_fasta']}"
seq_length = ecoli_data['seq_len']

dataset = FastaDataset(prom_path, non_prom_path, seq_len=seq_length,encoding_func=token_encode)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-4283933263.py in <cell line: 0>()
#       5 seq_length = ecoli_data['seq_len']
#       6
# ----> 7 dataset = FastaDataset(prom_path, non_prom_path, seq_len=seq_length,encoding_func=token_encode)
#
# /content/Promoter-Classification/utils/fasta_dataset.py in __init__(self, pos_fasta, neg_fasta, encoding_func, seq_len)
#      12         self.encoding_func = encoding_func
#      13
# ---> 14         self._load_fasta(pos_fasta, label=1)
#      15         self._load_fasta(neg_fasta, label=0)
#      16
#
# /content/Promoter-Classification/utils/fasta_dataset.py in _load_fasta(self, fasta_path, label)
#      16
#      17     def _load_fasta(self, fasta_path, label):
# ---> 18         for record in SeqIO.parse(fasta_path, "fasta"):
#      19             seq = str(record.seq).upper()
#      20             self.sequences.append(seq)
#
# /usr/local/lib/python3.12/dist-packages/Bio/SeqIO/__init__.py in parse(handle, format, alphabet)
#     672     iterator_generator = _FormatToIterator.get(format)
#     673     if iterator_generator:
# --> 674         return iterator_generator(handle)
#     675
#     676     raise ValueError(f"Unknown format '{format}'")
#
# /usr/local/lib/python3.12/dist-packages/Bio/SeqIO/FastaIO.py in __init__(self, source, alphabet)
#     194         if alphabet is not None:
#     195             raise ValueError("The alphabet argument is no longer supported")
# --> 196         super().__init__(source, fmt="Fasta")
#     197         line = self.stream.readline()
#     198         if not line:
#
# /usr/local/lib/python3.12/dist-packages/Bio/SeqIO/Interfaces.py in __init__(self, source, alphabet, fmt)
#      80         if isinstance(source, _PathLikeTypes):
#      81             mode = modes[0]
# ---> 82             self.stream = open(source, "r" + mode)
#      83         else:
#      84             value = source.read(0)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/Promoter-Classification/dataset/Arabidopsis_TATA_prom.fa'

# %% [markdown]
# # **Split Data**

# %%
train_dataset, val_dataset, test_dataset = dataset_split(dataset)

# %% [markdown]
# # **Dataset Visualization**

# %%
save_dir = f"/content/drive/MyDrive/checkpoints_bio/transformer/{ecoli_data['name']}"

# %%
labels = [dataset[i][1].item() for i in range(len(train_dataset))]
label_counts = pd.Series(labels).value_counts().sort_index()
label_counts.index = ['Non-Promoter', 'Promoter']

plt.figure(figsize=(6, 4))
sns.barplot(x=label_counts.index, y=label_counts.values, palette=['skyblue', 'salmon'])
plt.title(f'Class Distribution in {ecoli_data["name"]} Dataset')
plt.ylabel('Count')

os.makedirs(save_dir, exist_ok=True)
save_path = os.path.join(save_dir, "class_dist")
plt.savefig(save_path, bbox_inches='tight', dpi=300)

plt.show()

print("Class Distribution:")
print(label_counts)
# Out:
# /tmp/ipython-input-2583759941.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=label_counts.index, y=label_counts.values, palette=['skyblue', 'salmon'])
# Class Distribution:
# Non-Promoter    588
# Promoter        373
# Name: count, dtype: int64

# %% [markdown]
# # **Create Data Loaders**

# %%
batch_size = config['train']['batch_size']

train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_loader = torch.utils.data.DataLoader(val_dataset, batch_size=batch_size, shuffle=True)
test_loader = torch.utils.data.DataLoader(test_dataset, batch_size=batch_size, shuffle=True)

# %% [markdown]
# # **Train Model**

# %%
model = DNATransformer(seq_length,nhead=2,num_layers=1,dropout=0.1).to(device)
optimizer = torch.optim.Adam(model.parameters(), lr=1e-5)
criterion = torch.nn.BCELoss()

train = Train(model, train_loader,val_loader,optimizer,criterion,[TrainEvals()],device)
train.train(100,True)
# Out:
# Epoch 1/100 | Train Loss: 0.6485 | Val Loss: 0.5664
#   Train accuracy: 0.6462
#   Val accuracy: 0.7317
#   Train sensitivity: 0.1686
#   Val sensitivity: 0.0000
#   Train specificity: 0.8243
#   Val specificity: 1.0000
#   Train correlation_coef: -0.0084
#   Val correlation_coef: 0.0000
# Epoch 2/100 | Train Loss: 0.5329 | Val Loss: 0.5164
#   Train accuracy: 0.7284
#   Val accuracy: 0.7317
#   Train sensitivity: 0.0000
#   Val sensitivity: 0.0000
#   Train specificity: 1.0000
#   Val specificity: 1.0000
#   Train correlation_coef: 0.0000
#   Val correlation_coef: 0.0000
# Epoch 3/100 | Train Loss: 0.4905 | Val Loss: 0.4549
#   Train accuracy: 0.7284
#   Val accuracy: 0.7463
#   Train sensitivity: 0.0000
#   Val sensitivity: 0.0545
#   Train specificity: 1.0000
#   Val specificity: 1.0000
#   Train correlation_coef: 0.0000
#   Val correlation_coef: 0.2013
# Epoch 4/100 | Train Loss: 0.4623 | Val Loss: 0.4239
#   Train accuracy: 0.7430
#   Val accuracy: 0.7902
#   Train sensitivity: 0.0651
#   Val sensitivity: 0.2182
#   Train specificity: 0.9957
#   Val specificity: 1.0000
#   Train correlation_coef: 0.1896
#   Val correlation_coef: 0.4118
# Epoch 5/100 | Train Loss: 0.4307 | Val Loss: 0.3983
#   Train accuracy: 0.7867
#   Val accuracy: 0.7854
#   Train sensitivity: 0.3103
#   Val sensitivity: 0.2182
#   Train specificity: 0.9643
#   Val specificity: 0.9933
#   Train correlation_coef: 0.3899
#   Val correlation_coef: 0.3845
# Epoch 6/100 | Train Loss: 0.4202 | Val Loss: 0.3552
#   Train accuracy: 0.7908
#   Val accuracy: 0.8537
#   Train sensitivity: 0.3410
#   Val sensitivity: 0.5636
#   Train specificity: 0.9586
#   Val specificity: 0.9600
#   Train correlation_coef: 0.4060
#   Val correlation_coef: 0.6033
# Epoch 7/100 | Train Loss: 0.4270 | Val Loss: 0.3540
#   Train accuracy: 0.8075
#   Val accuracy: 0.8244
#   Train sensitivity: 0.5326
#   Val sensitivity: 0.4182
#   Train specificity: 0.9100
#   Val specificity: 0.9733
#   Train correlation_coef: 0.4831
#   Val correlation_coef: 0.5130
# Epoch 8/100 | Train Loss: 0.3857 | Val Loss: 0.3215
#   Train accuracy: 0.7992
#   Val accuracy: 0.8683
#   Train sensitivity: 0.3985
#   Val sensitivity: 0.6364
#   Train specificity: 0.9486
#   Val specificity: 0.9533
#   Train correlation_coef: 0.4375
#   Val correlation_coef: 0.6473
# Epoch 9/100 | Train Loss: 0.3708 | Val Loss: 0.3122
#   Train accuracy: 0.8210
#   Val accuracy: 0.8537
#   Train sensitivity: 0.5670
#   Val sensitivity: 0.5818
#   Train specificity: 0.9157
#   Val specificity: 0.9533
#   Train correlation_coef: 0.5223
#   Val correlation_coef: 0.6041
# Epoch 10/100 | Train Loss: 0.3991 | Val Loss: 0.3049
#   Train accuracy: 0.8179
#   Val accuracy: 0.8683
#   Train sensitivity: 0.5479
#   Val sensitivity: 0.6364
#   Train specificity: 0.9186
#   Val specificity: 0.9533
#   Train correlation_coef: 0.5111
#   Val correlation_coef: 0.6473
# Epoch 11/100 | Train Loss: 0.3614 | Val Loss: 0.3073
#   Train accuracy: 0.8252
#   Val accuracy: 0.8683
#   Train sensitivity: 0.5594
#   Val sensitivity: 0.6364
#   Train specificity: 0.9243
#   Val specificity: 0.9533
#   Train correlation_coef: 0.5309
#   Val correlation_coef: 0.6473
# Epoch 12/100 | Train Loss: 0.3719 | Val Loss: 0.3080
#   Train accuracy: 0.8377
#   Val accuracy: 0.8683
#   Train sensitivity: 0.6092
#   Val sensitivity: 0.7091
#   Train specificity: 0.9229
#   Val specificity: 0.9267
#   Train correlation_coef: 0.5697
#   Val correlation_coef: 0.6559
# Epoch 13/100 | Train Loss: 0.3533 | Val Loss: 0.3169
#   Train accuracy: 0.8293
#   Val accuracy: 0.8683
#   Train sensitivity: 0.6897
#   Val sensitivity: 0.6000
#   Train specificity: 0.8814
#   Val specificity: 0.9667
#   Train correlation_coef: 0.5697
#   Val correlation_coef: 0.6461
# Epoch 14/100 | Train Loss: 0.3535 | Val Loss: 0.2726
#   Train accuracy: 0.8304
#   Val accuracy: 0.8683
#   Train sensitivity: 0.5939
#   Val sensitivity: 0.7091
#   Train specificity: 0.9186
#   Val specificity: 0.9267
#   Train correlation_coef: 0.5497
#   Val correlation_coef: 0.6559
# Epoch 15/100 | Train Loss: 0.3617 | Val Loss: 0.2699
#   Train accuracy: 0.8366
#   Val accuracy: 0.8683
#   Train sensitivity: 0.6973
#   Val sensitivity: 0.6545
#   Train specificity: 0.8886
#   Val specificity: 0.9467
#   Train correlation_coef: 0.5866
#   Val correlation_coef: 0.6488
# Epoch 16/100 | Train Loss: 0.3564 | Val Loss: 0.2737
#   Train accuracy: 0.8398
#   Val accuracy: 0.8780
#   Train sensitivity: 0.7011
#   Val sensitivity: 0.6727
#   Train specificity: 0.8914
#   Val specificity: 0.9533
#   Train correlation_coef: 0.5940
#   Val correlation_coef: 0.6756
# Epoch 17/100 | Train Loss: 0.3334 | Val Loss: 0.2483
#   Train accuracy: 0.8460
#   Val accuracy: 0.8732
#   Train sensitivity: 0.7241
#   Val sensitivity: 0.6545
#   Train specificity: 0.8914
#   Val specificity: 0.9533
#   Train correlation_coef: 0.6127
#   Val correlation_coef: 0.6615
# Epoch 18/100 | Train Loss: 0.3336 | Val Loss: 0.2547
#   Train accuracy: 0.8387
#   Val accuracy: 0.8780
#   Train sensitivity: 0.6284
#   Val sensitivity: 0.7455
#   Train specificity: 0.9171
#   Val specificity: 0.9267
#   Train correlation_coef: 0.5757
#   Val correlation_coef: 0.6844
# Epoch 19/100 | Train Loss: 0.3175 | Val Loss: 0.2582
#   Train accuracy: 0.8512
#   Val accuracy: 0.8683
#   Train sensitivity: 0.6667
#   Val sensitivity: 0.7455
#   Train specificity: 0.9200
#   Val specificity: 0.9133
#   Train correlation_coef: 0.6116
#   Val correlation_coef: 0.6627
# Epoch 20/100 | Train Loss: 0.3223 | Val Loss: 0.2460
#   Train accuracy: 0.8554
#   Val accuracy: 0.8780
#   Train sensitivity: 0.7241
#   Val sensitivity: 0.7091
#   Train specificity: 0.9043
#   Val specificity: 0.9400
#   Train correlation_coef: 0.6323
#   Val correlation_coef: 0.6791
# Epoch 21/100 | Train Loss: 0.3130 | Val Loss: 0.2324
#   Train accuracy: 0.8574
#   Val accuracy: 0.8780
#   Train sensitivity: 0.7241
#   Val sensitivity: 0.7091
#   Train specificity: 0.9071
#   Val specificity: 0.9400
#   Train correlation_coef: 0.6367
#   Val correlation_coef: 0.6791
# Epoch 22/100 | Train Loss: 0.2923 | Val Loss: 0.2318
#   Train accuracy: 0.8637
#   Val accuracy: 0.8976
#   Train sensitivity: 0.7471
#   Val sensitivity: 0.7091
#   Train specificity: 0.9071
#   Val specificity: 0.9667
#   Train correlation_coef: 0.6551
#   Val correlation_coef: 0.7293
# Epoch 23/100 | Train Loss: 0.2828 | Val Loss: 0.1941
#   Train accuracy: 0.8751
#   Val accuracy: 0.9171
#   Train sensitivity: 0.7625
#   Val sensitivity: 0.8182
#   Train specificity: 0.9171
#   Val specificity: 0.9533
#   Train correlation_coef: 0.6829
#   Val correlation_coef: 0.7856
# Epoch 24/100 | Train Loss: 0.2623 | Val Loss: 0.1735
#   Train accuracy: 0.8803
#   Val accuracy: 0.9415
#   Train sensitivity: 0.7778
#   Val sensitivity: 0.8727
#   Train specificity: 0.9186
#   Val specificity: 0.9667
#   Train correlation_coef: 0.6972
#   Val correlation_coef: 0.8494
# Epoch 25/100 | Train Loss: 0.2531 | Val Loss: 0.1561
#   Train accuracy: 0.8980
#   Val accuracy: 0.9415
#   Train sensitivity: 0.7969
#   Val sensitivity: 0.8727
#   Train specificity: 0.9357
#   Val specificity: 0.9667
#   Train correlation_coef: 0.7399
#   Val correlation_coef: 0.8494
# Epoch 26/100 | Train Loss: 0.2321 | Val Loss: 0.1451
#   Train accuracy: 0.9043
#   Val accuracy: 0.9561
#   Train sensitivity: 0.7969
#   Val sensitivity: 0.9273
#   Train specificity: 0.9443
#   Val specificity: 0.9667
#   Train correlation_coef: 0.7544
#   Val correlation_coef: 0.8889
# Epoch 27/100 | Train Loss: 0.2187 | Val Loss: 0.1492
#   Train accuracy: 0.9063
#   Val accuracy: 0.9512
#   Train sensitivity: 0.8314
#   Val sensitivity: 0.8909
#   Train specificity: 0.9343
#   Val specificity: 0.9733
#   Train correlation_coef: 0.7639
#   Val correlation_coef: 0.8746
# Epoch 28/100 | Train Loss: 0.2157 | Val Loss: 0.1291
#   Train accuracy: 0.9043
#   Val accuracy: 0.9756
#   Train sensitivity: 0.7931
#   Val sensitivity: 0.9818
#   Train specificity: 0.9457
#   Val specificity: 0.9733
#   Train correlation_coef: 0.7540
#   Val correlation_coef: 0.9396
# Epoch 29/100 | Train Loss: 0.1990 | Val Loss: 0.1193
#   Train accuracy: 0.9178
#   Val accuracy: 0.9512
#   Train sensitivity: 0.8812
#   Val sensitivity: 0.8727
#   Train specificity: 0.9314
#   Val specificity: 0.9800
#   Train correlation_coef: 0.7972
#   Val correlation_coef: 0.8740
# Epoch 30/100 | Train Loss: 0.1997 | Val Loss: 0.1146
#   Train accuracy: 0.9251
#   Val accuracy: 0.9659
#   Train sensitivity: 0.8697
#   Val sensitivity: 0.9273
#   Train specificity: 0.9457
#   Val specificity: 0.9800
#   Train correlation_coef: 0.8116
#   Val correlation_coef: 0.9126
# Epoch 31/100 | Train Loss: 0.1826 | Val Loss: 0.1119
#   Train accuracy: 0.9292
#   Val accuracy: 0.9707
#   Train sensitivity: 0.8851
#   Val sensitivity: 0.9455
#   Train specificity: 0.9457
#   Val specificity: 0.9800
#   Train correlation_coef: 0.8230
#   Val correlation_coef: 0.9255
# Epoch 32/100 | Train Loss: 0.1948 | Val Loss: 0.1052
#   Train accuracy: 0.9209
#   Val accuracy: 0.9659
#   Train sensitivity: 0.8506
#   Val sensitivity: 0.9636
#   Train specificity: 0.9471
#   Val specificity: 0.9667
#   Train correlation_coef: 0.7997
#   Val correlation_coef: 0.9151
# Epoch 33/100 | Train Loss: 0.1855 | Val Loss: 0.1119
#   Train accuracy: 0.9188
#   Val accuracy: 0.9659
#   Train sensitivity: 0.8391
#   Val sensitivity: 0.9636
#   Train specificity: 0.9486
#   Val specificity: 0.9667
#   Train correlation_coef: 0.7935
#   Val correlation_coef: 0.9151
# Epoch 34/100 | Train Loss: 0.1708 | Val Loss: 0.1114
#   Train accuracy: 0.9334
#   Val accuracy: 0.9610
#   Train sensitivity: 0.8966
#   Val sensitivity: 0.9455
#   Train specificity: 0.9471
#   Val specificity: 0.9667
#   Train correlation_coef: 0.8340
#   Val correlation_coef: 0.9020
# Epoch 35/100 | Train Loss: 0.1697 | Val Loss: 0.1138
#   Train accuracy: 0.9334
#   Val accuracy: 0.9610
#   Train sensitivity: 0.9004
#   Val sensitivity: 0.9455
#   Train specificity: 0.9457
#   Val specificity: 0.9667
#   Train correlation_coef: 0.8345
#   Val correlation_coef: 0.9020
# Epoch 36/100 | Train Loss: 0.1699 | Val Loss: 0.1073
#   Train accuracy: 0.9313
#   Val accuracy: 0.9610
#   Train sensitivity: 0.8889
#   Val sensitivity: 0.9455
#   Train specificity: 0.9471
#   Val specificity: 0.9667
#   Train correlation_coef: 0.8283
#   Val correlation_coef: 0.9020
# Epoch 37/100 | Train Loss: 0.1625 | Val Loss: 0.1213
#   Train accuracy: 0.9344
#   Val accuracy: 0.9561
#   Train sensitivity: 0.9042
#   Val sensitivity: 0.9273
#   Train specificity: 0.9457
#   Val specificity: 0.9667
#   Train correlation_coef: 0.8373
#   Val correlation_coef: 0.8889
# Epoch 38/100 | Train Loss: 0.1589 | Val Loss: 0.0992
#   Train accuracy: 0.9324
#   Val accuracy: 0.9610
#   Train sensitivity: 0.8736
#   Val sensitivity: 0.9455
#   Train specificity: 0.9543
#   Val specificity: 0.9667
#   Train correlation_coef: 0.8288
#   Val correlation_coef: 0.9020
# Epoch 39/100 | Train Loss: 0.1607 | Val Loss: 0.1196
#   Train accuracy: 0.9376
#   Val accuracy: 0.9561
#   Train sensitivity: 0.9119
#   Val sensitivity: 0.9273
#   Train specificity: 0.9471
#   Val specificity: 0.9667
#   Train correlation_coef: 0.8454
#   Val correlation_coef: 0.8889
# Epoch 40/100 | Train Loss: 0.1552 | Val Loss: 0.1047
#   Train accuracy: 0.9386
#   Val accuracy: 0.9561
#   Train sensitivity: 0.8927
#   Val sensitivity: 0.9273
#   Train specificity: 0.9557
#   Val specificity: 0.9667
#   Train correlation_coef: 0.8454
#   Val correlation_coef: 0.8889
# Epoch 41/100 | Train Loss: 0.1491 | Val Loss: 0.1096
#   Train accuracy: 0.9396
#   Val accuracy: 0.9610
#   Train sensitivity: 0.8889
#   Val sensitivity: 0.9636
#   Train specificity: 0.9586
#   Val specificity: 0.9600
#   Train correlation_coef: 0.8475
#   Val correlation_coef: 0.9039
# Epoch 42/100 | Train Loss: 0.1527 | Val Loss: 0.1093
#   Train accuracy: 0.9417
#   Val accuracy: 0.9561
#   Train sensitivity: 0.9080
#   Val sensitivity: 0.9273
#   Train specificity: 0.9543
#   Val specificity: 0.9667
#   Train correlation_coef: 0.8543
#   Val correlation_coef: 0.8889
# Epoch 43/100 | Train Loss: 0.1506 | Val Loss: 0.1088
#   Train accuracy: 0.9386
#   Val accuracy: 0.9610
#   Train sensitivity: 0.8889
#   Val sensitivity: 0.9455
#   Train specificity: 0.9571
#   Val specificity: 0.9667
#   Train correlation_coef: 0.8450
#   Val correlation_coef: 0.9020
# Epoch 44/100 | Train Loss: 0.1478 | Val Loss: 0.1047
#   Train accuracy: 0.9396
#   Val accuracy: 0.9561
#   Train sensitivity: 0.9080
#   Val sensitivity: 0.9273
#   Train specificity: 0.9514
#   Val specificity: 0.9667
#   Train correlation_coef: 0.8496
#   Val correlation_coef: 0.8889
# Epoch 45/100 | Train Loss: 0.1438 | Val Loss: 0.1023
#   Train accuracy: 0.9417
#   Val accuracy: 0.9659
#   Train sensitivity: 0.8927
#   Val sensitivity: 0.9636
#   Train specificity: 0.9600
#   Val specificity: 0.9667
#   Train correlation_coef: 0.8527
#   Val correlation_coef: 0.9151
# Epoch 46/100 | Train Loss: 0.1464 | Val Loss: 0.1163
#   Train accuracy: 0.9480
#   Val accuracy: 0.9561
#   Train sensitivity: 0.9234
#   Val sensitivity: 0.9273
#   Train specificity: 0.9571
#   Val specificity: 0.9667
#   Train correlation_coef: 0.8704
#   Val correlation_coef: 0.8889
# Epoch 47/100 | Train Loss: 0.1492 | Val Loss: 0.1094
#   Train accuracy: 0.9376
#   Val accuracy: 0.9610
#   Train sensitivity: 0.8889
#   Val sensitivity: 0.9455
#   Train specificity: 0.9557
#   Val specificity: 0.9667
#   Train correlation_coef: 0.8426
#   Val correlation_coef: 0.9020
# Epoch 48/100 | Train Loss: 0.1446 | Val Loss: 0.1046
#   Train accuracy: 0.9417
#   Val accuracy: 0.9610
#   Train sensitivity: 0.9080
#   Val sensitivity: 0.9455
#   Train specificity: 0.9543
#   Val specificity: 0.9667
#   Train correlation_coef: 0.8543
#   Val correlation_coef: 0.9020
# Epoch 49/100 | Train Loss: 0.1398 | Val Loss: 0.1025
#   Train accuracy: 0.9417
#   Val accuracy: 0.9610
#   Train sensitivity: 0.8927
#   Val sensitivity: 0.9455
#   Train specificity: 0.9600
#   Val specificity: 0.9667
#   Train correlation_coef: 0.8527
#   Val correlation_coef: 0.9020
# Epoch 50/100 | Train Loss: 0.1393 | Val Loss: 0.1101
#   Train accuracy: 0.9386
#   Val accuracy: 0.9610
#   Train sensitivity: 0.8966
#   Val sensitivity: 0.9455
#   Train specificity: 0.9543
#   Val specificity: 0.9667
#   Train correlation_coef: 0.8458
#   Val correlation_coef: 0.9020
# Epoch 51/100 | Train Loss: 0.1334 | Val Loss: 0.1116
#   Train accuracy: 0.9459
#   Val accuracy: 0.9610
#   Train sensitivity: 0.9004
#   Val sensitivity: 0.9455
#   Train specificity: 0.9629
#   Val specificity: 0.9667
#   Train correlation_coef: 0.8632
#   Val correlation_coef: 0.9020
# Epoch 52/100 | Train Loss: 0.1389 | Val Loss: 0.1138
#   Train accuracy: 0.9480
#   Val accuracy: 0.9561
#   Train sensitivity: 0.9195
#   Val sensitivity: 0.8909
#   Train specificity: 0.9586
#   Val specificity: 0.9800
#   Train correlation_coef: 0.8699
#   Val correlation_coef: 0.8869
# Epoch 53/100 | Train Loss: 0.1325 | Val Loss: 0.1126
#   Train accuracy: 0.9490
#   Val accuracy: 0.9610
#   Train sensitivity: 0.9042
#   Val sensitivity: 0.9455
#   Train specificity: 0.9657
#   Val specificity: 0.9667
#   Train correlation_coef: 0.8710
#   Val correlation_coef: 0.9020
# Epoch 54/100 | Train Loss: 0.1398 | Val Loss: 0.1046
#   Train accuracy: 0.9448
#   Val accuracy: 0.9610
#   Train sensitivity: 0.9004
#   Val sensitivity: 0.9455
#   Train specificity: 0.9614
#   Val specificity: 0.9667
#   Train correlation_coef: 0.8608
#   Val correlation_coef: 0.9020
# Epoch 55/100 | Train Loss: 0.1329 | Val Loss: 0.1107
#   Train accuracy: 0.9438
#   Val accuracy: 0.9610
#   Train sensitivity: 0.9195
#   Val sensitivity: 0.9273
#   Train specificity: 0.9529
#   Val specificity: 0.9733
#   Train correlation_coef: 0.8604
#   Val correlation_coef: 0.9006
# Epoch 56/100 | Train Loss: 0.1294 | Val Loss: 0.1167
#   Train accuracy: 0.9469
#   Val accuracy: 0.9561
#   Train sensitivity: 0.9195
#   Val sensitivity: 0.9273
#   Train specificity: 0.9571
#   Val specificity: 0.9667
#   Train correlation_coef: 0.8675
#   Val correlation_coef: 0.8889
# Epoch 57/100 | Train Loss: 0.1336 | Val Loss: 0.1082
#   Train accuracy: 0.9438
#   Val accuracy: 0.9561
#   Train sensitivity: 0.9042
#   Val sensitivity: 0.9273
#   Train specificity: 0.9586
#   Val specificity: 0.9667
#   Train correlation_coef: 0.8587
#   Val correlation_coef: 0.8889
# Epoch 58/100 | Train Loss: 0.1336 | Val Loss: 0.1177
#   Train accuracy: 0.9417
#   Val accuracy: 0.9610
#   Train sensitivity: 0.9080
#   Val sensitivity: 0.9273
#   Train specificity: 0.9543
#   Val specificity: 0.9733
#   Train correlation_coef: 0.8543
#   Val correlation_coef: 0.9006
# Epoch 59/100 | Train Loss: 0.1230 | Val Loss: 0.1120
#   Train accuracy: 0.9532
#   Val accuracy: 0.9561
#   Train sensitivity: 0.9195
#   Val sensitivity: 0.9273
#   Train specificity: 0.9657
#   Val specificity: 0.9667
#   Train correlation_coef: 0.8821
#   Val correlation_coef: 0.8889
# Epoch 60/100 | Train Loss: 0.1229 | Val Loss: 0.1093
#   Train accuracy: 0.9459
#   Val accuracy: 0.9561
#   Train sensitivity: 0.9119
#   Val sensitivity: 0.9273
#   Train specificity: 0.9586
#   Val specificity: 0.9667
#   Train correlation_coef: 0.8643
#   Val correlation_coef: 0.8889
# Epoch 61/100 | Train Loss: 0.1271 | Val Loss: 0.1277
#   Train accuracy: 0.9490
#   Val accuracy: 0.9610
#   Train sensitivity: 0.9157
#   Val sensitivity: 0.9273
#   Train specificity: 0.9614
#   Val specificity: 0.9733
#   Train correlation_coef: 0.8720
#   Val correlation_coef: 0.9006
# Epoch 62/100 | Train Loss: 0.1219 | Val Loss: 0.1098
#   Train accuracy: 0.9532
#   Val accuracy: 0.9561
#   Train sensitivity: 0.9157
#   Val sensitivity: 0.9273
#   Train specificity: 0.9671
#   Val specificity: 0.9667
#   Train correlation_coef: 0.8818
#   Val correlation_coef: 0.8889
# Epoch 63/100 | Train Loss: 0.1258 | Val Loss: 0.1075
#   Train accuracy: 0.9469
#   Val accuracy: 0.9561
#   Train sensitivity: 0.9042
#   Val sensitivity: 0.9273
#   Train specificity: 0.9629
#   Val specificity: 0.9667
#   Train correlation_coef: 0.8660
#   Val correlation_coef: 0.8889
# Epoch 64/100 | Train Loss: 0.1230 | Val Loss: 0.1146
#   Train accuracy: 0.9532
#   Val accuracy: 0.9561
#   Train sensitivity: 0.9272
#   Val sensitivity: 0.9273
#   Train specificity: 0.9629
#   Val specificity: 0.9667
#   Train correlation_coef: 0.8828
#   Val correlation_coef: 0.8889
# Epoch 65/100 | Train Loss: 0.1327 | Val Loss: 0.1108
#   Train accuracy: 0.9542
#   Val accuracy: 0.9561
#   Train sensitivity: 0.9234
#   Val sensitivity: 0.9273
#   Train specificity: 0.9657
#   Val specificity: 0.9667
#   Train correlation_coef: 0.8849
#   Val correlation_coef: 0.8889
# Epoch 66/100 | Train Loss: 0.1674 | Val Loss: 0.1186
#   Train accuracy: 0.9501
#   Val accuracy: 0.9512
#   Train sensitivity: 0.9234
#   Val sensitivity: 0.9273
#   Train specificity: 0.9600
#   Val specificity: 0.9600
#   Train correlation_coef: 0.8752
#   Val correlation_coef: 0.8774
# Epoch 67/100 | Train Loss: 0.1340 | Val Loss: 0.1327
#   Train accuracy: 0.9480
#   Val accuracy: 0.9463
#   Train sensitivity: 0.9464
#   Val sensitivity: 0.8909
#   Train specificity: 0.9486
#   Val specificity: 0.9667
#   Train correlation_coef: 0.8733
#   Val correlation_coef: 0.8626
# Epoch 68/100 | Train Loss: 0.1224 | Val Loss: 0.1180
#   Train accuracy: 0.9511
#   Val accuracy: 0.9610
#   Train sensitivity: 0.9195
#   Val sensitivity: 0.9455
#   Train specificity: 0.9629
#   Val specificity: 0.9667
#   Train correlation_coef: 0.8772
#   Val correlation_coef: 0.9020
# Epoch 69/100 | Train Loss: 0.1223 | Val Loss: 0.1147
#   Train accuracy: 0.9553
#   Val accuracy: 0.9610
#   Train sensitivity: 0.9234
#   Val sensitivity: 0.9455
#   Train specificity: 0.9671
#   Val specificity: 0.9667
#   Train correlation_coef: 0.8873
#   Val correlation_coef: 0.9020
# Epoch 70/100 | Train Loss: 0.1187 | Val Loss: 0.1346
#   Train accuracy: 0.9563
#   Val accuracy: 0.9561
#   Train sensitivity: 0.9234
#   Val sensitivity: 0.9273
#   Train specificity: 0.9686
#   Val specificity: 0.9667
#   Train correlation_coef: 0.8898
#   Val correlation_coef: 0.8889
# Epoch 71/100 | Train Loss: 0.1213 | Val Loss: 0.1307
#   Train accuracy: 0.9532
#   Val accuracy: 0.9561
#   Train sensitivity: 0.9195
#   Val sensitivity: 0.9455
#   Train specificity: 0.9657
#   Val specificity: 0.9600
#   Train correlation_coef: 0.8821
#   Val correlation_coef: 0.8907
# Epoch 72/100 | Train Loss: 0.1133 | Val Loss: 0.1377
#   Train accuracy: 0.9532
#   Val accuracy: 0.9512
#   Train sensitivity: 0.9272
#   Val sensitivity: 0.9091
#   Train specificity: 0.9629
#   Val specificity: 0.9667
#   Train correlation_coef: 0.8828
#   Val correlation_coef: 0.8758
# Epoch 73/100 | Train Loss: 0.1198 | Val Loss: 0.1189
#   Train accuracy: 0.9521
#   Val accuracy: 0.9512
#   Train sensitivity: 0.9272
#   Val sensitivity: 0.9273
#   Train specificity: 0.9614
#   Val specificity: 0.9600
#   Train correlation_coef: 0.8804
#   Val correlation_coef: 0.8774
# Epoch 74/100 | Train Loss: 0.1105 | Val Loss: 0.1248
#   Train accuracy: 0.9563
#   Val accuracy: 0.9512
#   Train sensitivity: 0.9195
#   Val sensitivity: 0.9273
#   Train specificity: 0.9700
#   Val specificity: 0.9600
#   Train correlation_coef: 0.8895
#   Val correlation_coef: 0.8774
# Epoch 75/100 | Train Loss: 0.1097 | Val Loss: 0.1257
#   Train accuracy: 0.9553
#   Val accuracy: 0.9610
#   Train sensitivity: 0.9234
#   Val sensitivity: 0.9273
#   Train specificity: 0.9671
#   Val specificity: 0.9733
#   Train correlation_coef: 0.8873
#   Val correlation_coef: 0.9006
# Epoch 76/100 | Train Loss: 0.1176 | Val Loss: 0.1242
#   Train accuracy: 0.9563
#   Val accuracy: 0.9512
#   Train sensitivity: 0.9234
#   Val sensitivity: 0.9273
#   Train specificity: 0.9686
#   Val specificity: 0.9600
#   Train correlation_coef: 0.8898
#   Val correlation_coef: 0.8774
# Epoch 77/100 | Train Loss: 0.1136 | Val Loss: 0.1463
#   Train accuracy: 0.9573
#   Val accuracy: 0.9512
#   Train sensitivity: 0.9272
#   Val sensitivity: 0.9273
#   Train specificity: 0.9686
#   Val specificity: 0.9600
#   Train correlation_coef: 0.8926
#   Val correlation_coef: 0.8774
# Epoch 78/100 | Train Loss: 0.1176 | Val Loss: 0.1576
#   Train accuracy: 0.9501
#   Val accuracy: 0.9512
#   Train sensitivity: 0.9195
#   Val sensitivity: 0.9273
#   Train specificity: 0.9614
#   Val specificity: 0.9600
#   Train correlation_coef: 0.8748
#   Val correlation_coef: 0.8774
# Epoch 79/100 | Train Loss: 0.1124 | Val Loss: 0.1414
#   Train accuracy: 0.9553
#   Val accuracy: 0.9561
#   Train sensitivity: 0.9234
#   Val sensitivity: 0.9273
#   Train specificity: 0.9671
#   Val specificity: 0.9667
#   Train correlation_coef: 0.8873
#   Val correlation_coef: 0.8889
# Epoch 80/100 | Train Loss: 0.1099 | Val Loss: 0.1254
#   Train accuracy: 0.9542
#   Val accuracy: 0.9512
#   Train sensitivity: 0.9272
#   Val sensitivity: 0.9273
#   Train specificity: 0.9643
#   Val specificity: 0.9600
#   Train correlation_coef: 0.8852
#   Val correlation_coef: 0.8774
# Epoch 81/100 | Train Loss: 0.1087 | Val Loss: 0.1337
#   Train accuracy: 0.9615
#   Val accuracy: 0.9512
#   Train sensitivity: 0.9349
#   Val sensitivity: 0.9273
#   Train specificity: 0.9714
#   Val specificity: 0.9600
#   Train correlation_coef: 0.9031
#   Val correlation_coef: 0.8774
# Epoch 82/100 | Train Loss: 0.1317 | Val Loss: 0.1343
#   Train accuracy: 0.9563
#   Val accuracy: 0.9512
#   Train sensitivity: 0.9310
#   Val sensitivity: 0.9091
#   Train specificity: 0.9657
#   Val specificity: 0.9667
#   Train correlation_coef: 0.8904
#   Val correlation_coef: 0.8758
# Epoch 83/100 | Train Loss: 0.1247 | Val Loss: 0.1725
#   Train accuracy: 0.9469
#   Val accuracy: 0.9463
#   Train sensitivity: 0.8774
#   Val sensitivity: 0.9455
#   Train specificity: 0.9729
#   Val specificity: 0.9467
#   Train correlation_coef: 0.8643
#   Val correlation_coef: 0.8687
# Epoch 84/100 | Train Loss: 0.1156 | Val Loss: 0.1392
#   Train accuracy: 0.9532
#   Val accuracy: 0.9463
#   Train sensitivity: 0.9349
#   Val sensitivity: 0.9091
#   Train specificity: 0.9600
#   Val specificity: 0.9600
#   Train correlation_coef: 0.8836
#   Val correlation_coef: 0.8642
# Epoch 85/100 | Train Loss: 0.1163 | Val Loss: 0.1370
#   Train accuracy: 0.9532
#   Val accuracy: 0.9463
#   Train sensitivity: 0.9195
#   Val sensitivity: 0.9273
#   Train specificity: 0.9657
#   Val specificity: 0.9533
#   Train correlation_coef: 0.8821
#   Val correlation_coef: 0.8662
# Epoch 86/100 | Train Loss: 0.1075 | Val Loss: 0.1476
#   Train accuracy: 0.9532
#   Val accuracy: 0.9463
#   Train sensitivity: 0.9157
#   Val sensitivity: 0.9091
#   Train specificity: 0.9671
#   Val specificity: 0.9600
#   Train correlation_coef: 0.8818
#   Val correlation_coef: 0.8642
# Epoch 87/100 | Train Loss: 0.1157 | Val Loss: 0.1363
#   Train accuracy: 0.9542
#   Val accuracy: 0.9463
#   Train sensitivity: 0.9195
#   Val sensitivity: 0.9091
#   Train specificity: 0.9671
#   Val specificity: 0.9600
#   Train correlation_coef: 0.8846
#   Val correlation_coef: 0.8642
# Epoch 88/100 | Train Loss: 0.1145 | Val Loss: 0.1414
#   Train accuracy: 0.9563
#   Val accuracy: 0.9463
#   Train sensitivity: 0.9195
#   Val sensitivity: 0.9091
#   Train specificity: 0.9700
#   Val specificity: 0.9600
#   Train correlation_coef: 0.8895
#   Val correlation_coef: 0.8642
# Epoch 89/100 | Train Loss: 0.1006 | Val Loss: 0.1389
#   Train accuracy: 0.9636
#   Val accuracy: 0.9463
#   Train sensitivity: 0.9425
#   Val sensitivity: 0.9091
#   Train specificity: 0.9714
#   Val specificity: 0.9600
#   Train correlation_coef: 0.9086
#   Val correlation_coef: 0.8642
# Epoch 90/100 | Train Loss: 0.1049 | Val Loss: 0.1433
#   Train accuracy: 0.9636
#   Val accuracy: 0.9512
#   Train sensitivity: 0.9464
#   Val sensitivity: 0.9091
#   Train specificity: 0.9700
#   Val specificity: 0.9667
#   Train correlation_coef: 0.9089
#   Val correlation_coef: 0.8758
# Epoch 91/100 | Train Loss: 0.1090 | Val Loss: 0.1407
#   Train accuracy: 0.9605
#   Val accuracy: 0.9512
#   Train sensitivity: 0.9234
#   Val sensitivity: 0.9091
#   Train specificity: 0.9743
#   Val specificity: 0.9667
#   Train correlation_coef: 0.8998
#   Val correlation_coef: 0.8758
# Epoch 92/100 | Train Loss: 0.1049 | Val Loss: 0.1701
#   Train accuracy: 0.9563
#   Val accuracy: 0.9512
#   Train sensitivity: 0.9387
#   Val sensitivity: 0.9091
#   Train specificity: 0.9629
#   Val specificity: 0.9667
#   Train correlation_coef: 0.8912
#   Val correlation_coef: 0.8758
# Epoch 93/100 | Train Loss: 0.1092 | Val Loss: 0.1563
#   Train accuracy: 0.9563
#   Val accuracy: 0.9512
#   Train sensitivity: 0.9272
#   Val sensitivity: 0.9091
#   Train specificity: 0.9671
#   Val specificity: 0.9667
#   Train correlation_coef: 0.8901
#   Val correlation_coef: 0.8758
# Epoch 94/100 | Train Loss: 0.0945 | Val Loss: 0.1522
#   Train accuracy: 0.9646
#   Val accuracy: 0.9463
#   Train sensitivity: 0.9579
#   Val sensitivity: 0.8909
#   Train specificity: 0.9671
#   Val specificity: 0.9667
#   Train correlation_coef: 0.9123
#   Val correlation_coef: 0.8626
# Epoch 95/100 | Train Loss: 0.1127 | Val Loss: 0.1489
#   Train accuracy: 0.9511
#   Val accuracy: 0.9463
#   Train sensitivity: 0.9157
#   Val sensitivity: 0.9091
#   Train specificity: 0.9643
#   Val specificity: 0.9600
#   Train correlation_coef: 0.8769
#   Val correlation_coef: 0.8642
# Epoch 96/100 | Train Loss: 0.0974 | Val Loss: 0.1781
#   Train accuracy: 0.9615
#   Val accuracy: 0.9512
#   Train sensitivity: 0.9464
#   Val sensitivity: 0.9091
#   Train specificity: 0.9671
#   Val specificity: 0.9667
#   Train correlation_coef: 0.9040
#   Val correlation_coef: 0.8758
# Epoch 97/100 | Train Loss: 0.0991 | Val Loss: 0.1599
#   Train accuracy: 0.9584
#   Val accuracy: 0.9512
#   Train sensitivity: 0.9349
#   Val sensitivity: 0.9091
#   Train specificity: 0.9671
#   Val specificity: 0.9667
#   Train correlation_coef: 0.8957
#   Val correlation_coef: 0.8758
# Epoch 98/100 | Train Loss: 0.1081 | Val Loss: 0.1511
#   Train accuracy: 0.9605
#   Val accuracy: 0.9317
#   Train sensitivity: 0.9157
#   Val sensitivity: 0.9091
#   Train specificity: 0.9771
#   Val specificity: 0.9400
#   Train correlation_coef: 0.8994
#   Val correlation_coef: 0.8310
# Epoch 99/100 | Train Loss: 0.1003 | Val Loss: 0.1805
#   Train accuracy: 0.9594
#   Val accuracy: 0.9463
#   Train sensitivity: 0.9310
#   Val sensitivity: 0.9091
#   Train specificity: 0.9700
#   Val specificity: 0.9600
#   Train correlation_coef: 0.8978
#   Val correlation_coef: 0.8642
# Epoch 100/100 | Train Loss: 0.1085 | Val Loss: 0.1735
#   Train accuracy: 0.9584
#   Val accuracy: 0.9366
#   Train sensitivity: 0.9310
#   Val sensitivity: 0.9091
#   Train specificity: 0.9686
#   Val specificity: 0.9467
#   Train correlation_coef: 0.8954
#   Val correlation_coef: 0.8418

# %% [markdown]
# # **Evaluation**

# %%
fpr, tpr, roc_auc, all_labels, all_predictions = calculate_roc_data(model,test_loader,False,device)

# %%
plot_roc_curve(fpr, tpr, roc_auc,save_dir=save_dir,
                file_name='bacillus_roc_curve'
               )

# %%
# Call the function to find the optimal threshold
optimal_threshold, max_f1_score = find_optimal_threshold(all_labels, all_predictions, thresholds)

print(f"Optimal Threshold: {optimal_threshold:.4f}")
print(f"Maximum F1-score at optimal threshold: {max_f1_score:.4f}")
# Out:
# Optimal Threshold: 0.6718
# Maximum F1-score at optimal threshold: 0.8793

# %%
# Assuming optimal_threshold is already defined or will be defined next
# For now, let's plot with a default 0.5 or the previously calculated optimal_threshold if it exists
plot_confusion_matrix(all_labels, all_predictions, threshold=optimal_threshold, title='Confusion Matrix with Optimal Threshold',
                      save_dir=save_dir,
                      file_name='bacillus_confusion_matrix'
                      )

# %%
# Call the function to calculate and print metrics using the optimal_threshold
metrics_dict = calculate_metrics(all_labels, all_predictions, optimal_threshold)

print(f"Metrics at Optimal Threshold ({optimal_threshold:.4f}):")
for metric_name, value in metrics_dict.items():
    print(f"  {metric_name}: {value:.4f}")
# Out:
# Metrics at Optimal Threshold (0.6718):
#   Accuracy: 0.9324
#   Precision: 0.8644
#   Recall (Sensitivity): 0.8947
#   Negative Recall (Specificity): 0.9467
#   F1-Score: 0.8793

# %%
seq = dataset.sequences[0]

kmers = random_substitution_top_kmers(
    model,
    seq,
    encoding_func=token_encode,
    seq_len=81,
    window_size=7,
    top_k=10,
    device=device
)

for pos, kmer, score in kmers:
    print(f"Position {pos}: {kmer}  (importance={score:.4f})")
# Out:
# Position 51: CAATAAA  (importance=0.9951)
# Position 48: CTACAAT  (importance=0.9949)
# Position 49: TACAATA  (importance=0.9939)
# Position 47: ACTACAA  (importance=0.9938)
# Position 50: ACAATAA  (importance=0.9934)
# Position 45: TGACTAC  (importance=0.9919)
# Position 44: GTGACTA  (importance=0.9883)
# Position 52: AATAAAG  (importance=0.9504)
# Position 46: GACTACA  (importance=0.7567)
# Position 56: AAGGGGA  (importance=0.0316)

# %%
import json
import os
json_file_name = "bacillus_json"

# Prepare kmer data for JSON serialization (convert numpy types to native Python types)
kmer_data = [
    {
        "position": int(pos),
        "kmer": kmer,
        "importance": float(score)
    }
    for pos, kmer, score in kmers
]

# Prepare metrics data for JSON serialization (convert numpy types to native Python types)
# Ensure all values in metrics_dict are native Python types
metrics_serializable = {
    key: float(value) if isinstance(value, np.floating) else value
    for key, value in metrics_dict.items()
}

# Combine all data into a single dictionary
output_data = {
    "top_kmers": kmer_data,
    "metrics": metrics_serializable
}

# Define the full path for the JSON file
json_file_path = os.path.join(save_dir, f"{json_file_name}.json")

# Save the data to a JSON file
with open(json_file_path, 'w') as f:
    json.dump(output_data, f, indent=4)

print(f"Successfully saved top kmers and metrics to {json_file_path}")
# Out:
# Successfully saved top kmers and metrics to /content/drive/MyDrive/checkpoints_bio/transformer/Bacillus subtilis/bacillus_json.json
